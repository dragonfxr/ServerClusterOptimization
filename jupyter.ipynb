# %%
import sys 
import os
import numpy as np 
import random

# %%
def readFile(n, fileName):
    file = []
    with open (f"config/{fileName}_{n}.txt") as data:
        for row in data:
            file.append(row.replace('\n', ''))
        return file

# %%
def add_to_jobs(jobList, job):
    jobList.append(job)
    jobList.sort(key=lambda x: x.eventTime)

# %%
def queue_to_server(queue, jobList, masterclock):
    nextJob = queue.pop(0)
    nextJob.eventTime = masterclock
    add_to_jobs(jobList, nextJob)
    # print("server has a space, move from queue to server")

# %%
def log(job, masterclock):
    print("Master clock:", masterclock)
    print("Job:", job.index)
    print("Job group:", job.group)
    print("Job type:", job.type)
    print("Arrival Time", job.arrivalTime)
    print("Service Time:", job.serviceTime)

# %%
def mrt(jobs):
    response_times = {"0":0,"1":0}
    n = {"0":0, "1":0}
    mean = {"0":0, "1":0}
    for arr_time, dep_time, group in jobs:
        if group != "r0":
            mean[group] += (dep_time - arr_time)
            n[group] += 1
            
    response_times["0"] = mean["0"] / n["0"]
    response_times["1"] = mean["1"] / n["1"]

    return response_times

# %%
def output(s, completed_jobs, response_times):
    with open(f"output/mrt_{s}.txt", "w") as mrt_file:
                mrt_file.write(f"{mrt(completed_jobs)["0"]} "+ f"{mrt(completed_jobs)["1"]}")

    # Save dep values to a file
    with open(f"output/dep_{s}.txt", "w") as dep_file:
        for l in completed_jobs:
            dep_file.write(" ".join(map(str, l)) + "\n")

# %%
class job:
    def __init__(self, arrivalTime, serviceTime, group, index):
        self.arrivalTime = arrivalTime
        self.serviceTime = float(serviceTime)
        self.group = group
        self.departureTime = float(arrivalTime) + float(serviceTime)
        self.eventTime = arrivalTime
        self.index = index
        self.type = "Arrival"

# %%
def generate_groups(p0, n):
    jobsGroup = []
    for _ in range(n):
        random_number = random.random()
        if random_number < p0:
            jobsGroup.append("0")
        else:
            jobsGroup.append("1")
    return jobsGroup

# %%
def generate_arrivals(Lamba, alpha_2l, alpha_2u, endTime):
    interArrivalTime = []

    a1k = np.random.exponential(1 / Lamba)
    a2k = np.random.uniform(alpha_2l, alpha_2u)
    while True:
        if not interArrivalTime:
            ak = a1k * a2k
        else:
            ak = interArrivalTime[-1] + (a1k * a2k)
        if ak > endTime:
            break
        interArrivalTime.append(ak)
    return interArrivalTime

# %%
def inverse_pdf0(g, alpha, beta, eta):
    gamma = alpha**(-eta) - beta**(-eta)
    return (eta/(gamma * g)) ** (1/(eta+1))

def inverse_pdf1(g, alpha, eta):
    gamma = alpha**(-eta)
    return (eta/(gamma * g)) ** (1/(eta+1))

# %%
def generate_services(alpha0, beta0, eta0, alpha1, eta1, interArrivalTime, jobsGroup):
    serviceTime = []
    rand_values = np.random.uniform(size=len(interArrivalTime))
    for i in range(len(interArrivalTime)):
        if jobsGroup[i] == "0":
            serviceTime.append(inverse_pdf0(rand_values[i], alpha0, beta0, eta0))
        else:
            serviceTime.append(inverse_pdf1(rand_values[i], alpha1, eta1))

    return serviceTime

# %%
def get_all_jobs(mode, interArrivalFile, serviceFile, paraFile):
    arrivalTime = []
    serviceTime = []
    jobsGroup = []

    jobList = []

    if mode == "trace":
        interArrivalTime = list(float(i) for i in interArrivalFile)

        for line in serviceFile:
            serviceTime.append(line.split(" ")[0])
            jobsGroup.append(line.split(" ")[1])

        arrivalTime = np.cumsum(interArrivalTime)
        
        for i in range(len(interArrivalFile)):
            jobList.append(job(arrivalTime[i], serviceTime[i], jobsGroup[i], index=i))

    elif mode == "random":
        endTime = int(paraFile[3])
        Lamba, alpha_2l, alpha_2u = tuple(float(e) for e in interArrivalFile[0].split())
        p0 = float(serviceFile[0])
        alpha0, beta0, eta0  = tuple(float(e) for e in serviceFile[1].split())
        alpha1, eta1  = tuple(float(e) for e in serviceFile[2].split())

        arrivalTime = generate_arrivals(Lamba, alpha_2l, alpha_2u, endTime)
        jobsGroup = generate_groups(p0, len(arrivalTime))
        serviceTime = generate_services(alpha0, beta0, eta0, alpha1, eta1, arrivalTime, jobsGroup)
        
        for i in range(len(arrivalTime)):
            jobList.append(job(arrivalTime[i], serviceTime[i], jobsGroup[i], index=i))
        
        
    return jobList

# %%
def main(s):
    # Read all files:
    interArrivalFile = readFile(s, 'interarrival')
    mode = readFile(s, 'mode')[0]
    paraFile = readFile(s, 'para')
    serviceFile = readFile(s, 'service')

    n = int(paraFile[0])
    n0 = int(paraFile[1])
    Tlimit = float(paraFile[2])

    masterclock = 0
    group0 = 0
    group1 = 0
    queue0 = []
    queue1 = []

    completed_jobs = []
    response_times = {"0":0,"1":0}

    jobList = get_all_jobs(mode, interArrivalFile, serviceFile, paraFile)
    
    while jobList:
        currentJob = jobList.pop(0)
        masterclock = currentJob.eventTime
        if currentJob.type == "Arrival":
            # log(currentJob, masterclock)
            if currentJob.group == "0":
                if group0 != n0:
                    # print("Group 0 has a space.")
                    group0 += 1
                    if currentJob.serviceTime > Tlimit:
                        currentJob.departureTime = masterclock + Tlimit
                        currentJob.eventTime = currentJob.departureTime
                        currentJob.group = "R"
                        currentJob.type = "Departure"
                        add_to_jobs(jobList, currentJob)
                        # print("Job", f"{currentJob.index}", "cannot finish, need to go to group1 later.")
                    else:
                        currentJob.departureTime = masterclock + currentJob.serviceTime
                        currentJob.eventTime = currentJob.departureTime
                        currentJob.type = "Departure"
                        add_to_jobs(jobList,currentJob)
                        # print("Job", f"{currentJob.index}", "will finish at", f"{currentJob.departureTime}")
                else:
                    print("Group 0 is full")
                    queue0.append(currentJob)
                    # print("Job",f"{currentJob.index}","to queue0: ", currentJob.eventTime)
            elif currentJob.group == "1" or currentJob.group == "r0":
                if group1 != n-n0:
                    # print("Group 1 has a space")
                    group1 += 1
                    currentJob.departureTime = masterclock + currentJob.serviceTime
                    currentJob.eventTime = currentJob.departureTime
                    currentJob.type = "Departure"
                    add_to_jobs(jobList, currentJob)
                    # print("Job", f"{currentJob.index}", "will finish at", f"{currentJob.departureTime}")
                else:
                    # print("Group 1 is full")
                    queue1.append(currentJob)
                    # print("Job",f"{currentJob.index}","to queue1: ", currentJob.eventTime)
        elif currentJob.type ==  "Departure":
            # log(currentJob, masterclock)
            if currentJob.group == "0":
                # print("Job", f"{currentJob.index}", "finished.")
                completed_jobs.append((currentJob.arrivalTime, masterclock, currentJob.group))
                if queue0:
                    queue_to_server(queue0, jobList, masterclock)
                group0 -= 1
            elif currentJob.group == "R":
                currentJob.type = "Arrival"
                currentJob.departureTime = masterclock + currentJob.serviceTime
                currentJob.eventTime = masterclock
                currentJob.group = "r0"
                add_to_jobs(jobList, currentJob)
                # print("Job", f"{currentJob.index}", "has moved to group 1")
                if queue0:
                    queue_to_server(queue0, jobList, masterclock)
                group0 -= 1
            else:
                # print("Job", f"{currentJob.index}", "finished.")
                completed_jobs.append((currentJob.arrivalTime, masterclock, currentJob.group))
                if queue1:
                    queue_to_server(queue1, jobList, masterclock)
                group1 -= 1
        # print("-----------------------------")
    # print(completed_jobs)
    # print(mrt(completed_jobs)["0"], mrt(completed_jobs)["1"])
    output(s, completed_jobs, response_times)

# %%
main(4)
# Out:
# [2.0548651661904644, 4.109730332380929, 6.164595498571393, 8.219460664761858, 10.274325830952321, 12.329190997142785, 14.384056163333248, 16.438921329523712, 18.493786495714176, 20.54865166190464, 22.603516828095103, 24.658381994285566, 26.71324716047603, 28.768112326666493, 30.822977492856957, 32.877842659047424, 34.93270782523789, 36.98757299142836, 39.042438157618825, 41.09730332380929, 43.15216848999976, 45.20703365619023, 47.261898822380694, 49.31676398857116, 51.37162915476163, 53.426494320952095, 55.48135948714256, 57.53622465333303, 59.591089819523496, 61.64595498571396, 63.70082015190443, 65.75568531809489, 67.81055048428536, 69.86541565047582, 71.92028081666629, 73.97514598285676, 76.03001114904723, 78.0848763152377, 80.13974148142816, 82.19460664761863, 84.2494718138091, 86.30433697999956, 88.35920214619003, 90.4140673123805, 92.46893247857096, 94.52379764476143, 96.5786628109519, 98.63352797714236, 100.68839314333283, 102.7432583095233, 104.79812347571377, 106.85298864190423, 108.9078538080947, 110.96271897428517, 113.01758414047563, 115.0724493066661, 117.12731447285657, 119.18217963904704, 121.2370448052375, 123.29190997142797, 125.34677513761844, 127.4016403038089, 129.45650546999937, 131.51137063618984, 133.5662358023803, 135.62110096857077, 137.67596613476124, 139.7308313009517, 141.78569646714217, 143.84056163333264, 145.8954267995231, 147.95029196571357, 150.00515713190404, 152.0600222980945, 154.11488746428498, 156.16975263047544, 158.2246177966659, 160.27948296285638, 162.33434812904684, 164.3892132952373, 166.44407846142778, 168.49894362761825, 170.5538087938087, 172.60867395999918, 174.66353912618965, 176.71840429238011, 178.77326945857058, 180.82813462476105, 182.88299979095152, 184.93786495714198, 186.99273012333245, 189.04759528952292, 191.10246045571338, 193.15732562190385, 195.21219078809432, 197.26705595428479, 199.32192112047525]
# Master clock: 2.0548651661904644
# Job: 0
# Job group: 0
# Job type: Arrival
# Arrival Time 2.0548651661904644
# Service Time: 1.8791255642787754
# Group 0 has a space.
# Job 0 will finish at 3.93399073046924
# -----------------------------
# Master clock: 3.93399073046924
# Job: 0
# Job group: 0
# Job type: Departure
# Arrival Time 2.0548651661904644
# Service Time: 1.8791255642787754
# Job 0 finished.
# -----------------------------
# Master clock: 4.109730332380929
# Job: 1
# Job group: 0
# Job type: Arrival
# Arrival Time 4.109730332380929
# Service Time: 3.7701202705024737
# Group 0 has a space.
# Job 1 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 6.164595498571393
# Job: 2
# Job group: 1
# Job type: Arrival
# Arrival Time 6.164595498571393
# Service Time: 3.918177360725348
# Group 1 has a space
# Job 2 will finish at 10.08277285929674
# -----------------------------
# Master clock: 7.2097303323809285
# Job: 1
# Job group: R
# Job type: Departure
# Arrival Time 4.109730332380929
# Service Time: 3.7701202705024737
# Job 1 has moved to group 1
# -----------------------------
# Master clock: 7.2097303323809285
# Job: 1
# Job group: r0
# Job type: Arrival
# Arrival Time 4.109730332380929
# Service Time: 3.7701202705024737
# Group 1 has a space
# Job 1 will finish at 10.979850602883403
# -----------------------------
# Master clock: 8.219460664761858
# Job: 3
# Job group: 1
# Job type: Arrival
# Arrival Time 8.219460664761858
# Service Time: 4.6594463207489305
# Group 1 has a space
# Job 3 will finish at 12.878906985510788
# -----------------------------
# Master clock: 10.08277285929674
# Job: 2
# Job group: 1
# Job type: Departure
# Arrival Time 6.164595498571393
# Service Time: 3.918177360725348
# Job 2 finished.
# -----------------------------
# Master clock: 10.274325830952321
# Job: 4
# Job group: 0
# Job type: Arrival
# Arrival Time 10.274325830952321
# Service Time: 2.2434580109152042
# Group 0 has a space.
# Job 4 will finish at 12.517783841867526
# -----------------------------
# Master clock: 10.979850602883403
# Job: 1
# Job group: r0
# Job type: Departure
# Arrival Time 4.109730332380929
# Service Time: 3.7701202705024737
# Job 1 finished.
# -----------------------------
# Master clock: 12.329190997142785
# Job: 5
# Job group: 0
# Job type: Arrival
# Arrival Time 12.329190997142785
# Service Time: 2.3460718173136583
# Group 0 has a space.
# Job 5 will finish at 14.675262814456444
# -----------------------------
# Master clock: 12.517783841867526
# Job: 4
# Job group: 0
# Job type: Departure
# Arrival Time 10.274325830952321
# Service Time: 2.2434580109152042
# Job 4 finished.
# -----------------------------
# Master clock: 12.878906985510788
# Job: 3
# Job group: 1
# Job type: Departure
# Arrival Time 8.219460664761858
# Service Time: 4.6594463207489305
# Job 3 finished.
# -----------------------------
# Master clock: 14.384056163333248
# Job: 6
# Job group: 0
# Job type: Arrival
# Arrival Time 14.384056163333248
# Service Time: 4.081819178687962
# Group 0 has a space.
# Job 6 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 14.675262814456444
# Job: 5
# Job group: 0
# Job type: Departure
# Arrival Time 12.329190997142785
# Service Time: 2.3460718173136583
# Job 5 finished.
# -----------------------------
# Master clock: 16.438921329523712
# Job: 7
# Job group: 0
# Job type: Arrival
# Arrival Time 16.438921329523712
# Service Time: 1.9276398155860779
# Group 0 has a space.
# Job 7 will finish at 18.36656114510979
# -----------------------------
# Master clock: 17.48405616333325
# Job: 6
# Job group: R
# Job type: Departure
# Arrival Time 14.384056163333248
# Service Time: 4.081819178687962
# Job 6 has moved to group 1
# -----------------------------
# Master clock: 17.48405616333325
# Job: 6
# Job group: r0
# Job type: Arrival
# Arrival Time 14.384056163333248
# Service Time: 4.081819178687962
# Group 1 has a space
# Job 6 will finish at 21.56587534202121
# -----------------------------
# Master clock: 18.36656114510979
# Job: 7
# Job group: 0
# Job type: Departure
# Arrival Time 16.438921329523712
# Service Time: 1.9276398155860779
# Job 7 finished.
# -----------------------------
# Master clock: 18.493786495714176
# Job: 8
# Job group: 1
# Job type: Arrival
# Arrival Time 18.493786495714176
# Service Time: 3.260508795914844
# Group 1 has a space
# Job 8 will finish at 21.75429529162902
# -----------------------------
# Master clock: 20.54865166190464
# Job: 9
# Job group: 0
# Job type: Arrival
# Arrival Time 20.54865166190464
# Service Time: 1.9554942951180292
# Group 0 has a space.
# Job 9 will finish at 22.50414595702267
# -----------------------------
# Master clock: 21.56587534202121
# Job: 6
# Job group: r0
# Job type: Departure
# Arrival Time 14.384056163333248
# Service Time: 4.081819178687962
# Job 6 finished.
# -----------------------------
# Master clock: 21.75429529162902
# Job: 8
# Job group: 1
# Job type: Departure
# Arrival Time 18.493786495714176
# Service Time: 3.260508795914844
# Job 8 finished.
# -----------------------------
# Master clock: 22.50414595702267
# Job: 9
# Job group: 0
# Job type: Departure
# Arrival Time 20.54865166190464
# Service Time: 1.9554942951180292
# Job 9 finished.
# -----------------------------
# Master clock: 22.603516828095103
# Job: 10
# Job group: 0
# Job type: Arrival
# Arrival Time 22.603516828095103
# Service Time: 1.5147955138845137
# Group 0 has a space.
# Job 10 will finish at 24.118312341979617
# -----------------------------
# Master clock: 24.118312341979617
# Job: 10
# Job group: 0
# Job type: Departure
# Arrival Time 22.603516828095103
# Service Time: 1.5147955138845137
# Job 10 finished.
# -----------------------------
# Master clock: 24.658381994285566
# Job: 11
# Job group: 0
# Job type: Arrival
# Arrival Time 24.658381994285566
# Service Time: 4.209755685534823
# Group 0 has a space.
# Job 11 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 26.71324716047603
# Job: 12
# Job group: 0
# Job type: Arrival
# Arrival Time 26.71324716047603
# Service Time: 1.7245659645568228
# Group 0 has a space.
# Job 12 will finish at 28.437813125032854
# -----------------------------
# Master clock: 27.758381994285568
# Job: 11
# Job group: R
# Job type: Departure
# Arrival Time 24.658381994285566
# Service Time: 4.209755685534823
# Job 11 has moved to group 1
# -----------------------------
# Master clock: 27.758381994285568
# Job: 11
# Job group: r0
# Job type: Arrival
# Arrival Time 24.658381994285566
# Service Time: 4.209755685534823
# Group 1 has a space
# Job 11 will finish at 31.96813767982039
# -----------------------------
# Master clock: 28.437813125032854
# Job: 12
# Job group: 0
# Job type: Departure
# Arrival Time 26.71324716047603
# Service Time: 1.7245659645568228
# Job 12 finished.
# -----------------------------
# Master clock: 28.768112326666493
# Job: 13
# Job group: 0
# Job type: Arrival
# Arrival Time 28.768112326666493
# Service Time: 2.252814164887104
# Group 0 has a space.
# Job 13 will finish at 31.020926491553595
# -----------------------------
# Master clock: 30.822977492856957
# Job: 14
# Job group: 0
# Job type: Arrival
# Arrival Time 30.822977492856957
# Service Time: 1.7521200743183531
# Group 0 has a space.
# Job 14 will finish at 32.57509756717531
# -----------------------------
# Master clock: 31.020926491553595
# Job: 13
# Job group: 0
# Job type: Departure
# Arrival Time 28.768112326666493
# Service Time: 2.252814164887104
# Job 13 finished.
# -----------------------------
# Master clock: 31.96813767982039
# Job: 11
# Job group: r0
# Job type: Departure
# Arrival Time 24.658381994285566
# Service Time: 4.209755685534823
# Job 11 finished.
# -----------------------------
# Master clock: 32.57509756717531
# Job: 14
# Job group: 0
# Job type: Departure
# Arrival Time 30.822977492856957
# Service Time: 1.7521200743183531
# Job 14 finished.
# -----------------------------
# Master clock: 32.877842659047424
# Job: 15
# Job group: 0
# Job type: Arrival
# Arrival Time 32.877842659047424
# Service Time: 2.2173222048513543
# Group 0 has a space.
# Job 15 will finish at 35.09516486389878
# -----------------------------
# Master clock: 34.93270782523789
# Job: 16
# Job group: 0
# Job type: Arrival
# Arrival Time 34.93270782523789
# Service Time: 1.9265706651635737
# Group 0 has a space.
# Job 16 will finish at 36.859278490401465
# -----------------------------
# Master clock: 35.09516486389878
# Job: 15
# Job group: 0
# Job type: Departure
# Arrival Time 32.877842659047424
# Service Time: 2.2173222048513543
# Job 15 finished.
# -----------------------------
# Master clock: 36.859278490401465
# Job: 16
# Job group: 0
# Job type: Departure
# Arrival Time 34.93270782523789
# Service Time: 1.9265706651635737
# Job 16 finished.
# -----------------------------
# Master clock: 36.98757299142836
# Job: 17
# Job group: 1
# Job type: Arrival
# Arrival Time 36.98757299142836
# Service Time: 3.832396063868326
# Group 1 has a space
# Job 17 will finish at 40.81996905529668
# -----------------------------
# Master clock: 39.042438157618825
# Job: 18
# Job group: 0
# Job type: Arrival
# Arrival Time 39.042438157618825
# Service Time: 1.5684629417334837
# Group 0 has a space.
# Job 18 will finish at 40.61090109935231
# -----------------------------
# Master clock: 40.61090109935231
# Job: 18
# Job group: 0
# Job type: Departure
# Arrival Time 39.042438157618825
# Service Time: 1.5684629417334837
# Job 18 finished.
# -----------------------------
# Master clock: 40.81996905529668
# Job: 17
# Job group: 1
# Job type: Departure
# Arrival Time 36.98757299142836
# Service Time: 3.832396063868326
# Job 17 finished.
# -----------------------------
# Master clock: 41.09730332380929
# Job: 19
# Job group: 1
# Job type: Arrival
# Arrival Time 41.09730332380929
# Service Time: 3.379701768904998
# Group 1 has a space
# Job 19 will finish at 44.47700509271429
# -----------------------------
# Master clock: 43.15216848999976
# Job: 20
# Job group: 0
# Job type: Arrival
# Arrival Time 43.15216848999976
# Service Time: 2.231044658668531
# Group 0 has a space.
# Job 20 will finish at 45.38321314866829
# -----------------------------
# Master clock: 44.47700509271429
# Job: 19
# Job group: 1
# Job type: Departure
# Arrival Time 41.09730332380929
# Service Time: 3.379701768904998
# Job 19 finished.
# -----------------------------
# Master clock: 45.20703365619023
# Job: 21
# Job group: 0
# Job type: Arrival
# Arrival Time 45.20703365619023
# Service Time: 3.0450518186000597
# Group 0 has a space.
# Job 21 will finish at 48.252085474790285
# -----------------------------
# Master clock: 45.38321314866829
# Job: 20
# Job group: 0
# Job type: Departure
# Arrival Time 43.15216848999976
# Service Time: 2.231044658668531
# Job 20 finished.
# -----------------------------
# Master clock: 47.261898822380694
# Job: 22
# Job group: 1
# Job type: Arrival
# Arrival Time 47.261898822380694
# Service Time: 3.5050096534877855
# Group 1 has a space
# Job 22 will finish at 50.766908475868476
# -----------------------------
# Master clock: 48.252085474790285
# Job: 21
# Job group: 0
# Job type: Departure
# Arrival Time 45.20703365619023
# Service Time: 3.0450518186000597
# Job 21 finished.
# -----------------------------
# Master clock: 49.31676398857116
# Job: 23
# Job group: 0
# Job type: Arrival
# Arrival Time 49.31676398857116
# Service Time: 2.4056824121666764
# Group 0 has a space.
# Job 23 will finish at 51.72244640073784
# -----------------------------
# Master clock: 50.766908475868476
# Job: 22
# Job group: 1
# Job type: Departure
# Arrival Time 47.261898822380694
# Service Time: 3.5050096534877855
# Job 22 finished.
# -----------------------------
# Master clock: 51.37162915476163
# Job: 24
# Job group: 0
# Job type: Arrival
# Arrival Time 51.37162915476163
# Service Time: 1.9125515477436346
# Group 0 has a space.
# Job 24 will finish at 53.28418070250526
# -----------------------------
# Master clock: 51.72244640073784
# Job: 23
# Job group: 0
# Job type: Departure
# Arrival Time 49.31676398857116
# Service Time: 2.4056824121666764
# Job 23 finished.
# -----------------------------
# Master clock: 53.28418070250526
# Job: 24
# Job group: 0
# Job type: Departure
# Arrival Time 51.37162915476163
# Service Time: 1.9125515477436346
# Job 24 finished.
# -----------------------------
# Master clock: 53.426494320952095
# Job: 25
# Job group: 0
# Job type: Arrival
# Arrival Time 53.426494320952095
# Service Time: 1.803964991622916
# Group 0 has a space.
# Job 25 will finish at 55.23045931257501
# -----------------------------
# Master clock: 55.23045931257501
# Job: 25
# Job group: 0
# Job type: Departure
# Arrival Time 53.426494320952095
# Service Time: 1.803964991622916
# Job 25 finished.
# -----------------------------
# Master clock: 55.48135948714256
# Job: 26
# Job group: 1
# Job type: Arrival
# Arrival Time 55.48135948714256
# Service Time: 5.360020406597597
# Group 1 has a space
# Job 26 will finish at 60.84137989374016
# -----------------------------
# Master clock: 57.53622465333303
# Job: 27
# Job group: 0
# Job type: Arrival
# Arrival Time 57.53622465333303
# Service Time: 1.5411147929649964
# Group 0 has a space.
# Job 27 will finish at 59.077339446298026
# -----------------------------
# Master clock: 59.077339446298026
# Job: 27
# Job group: 0
# Job type: Departure
# Arrival Time 57.53622465333303
# Service Time: 1.5411147929649964
# Job 27 finished.
# -----------------------------
# Master clock: 59.591089819523496
# Job: 28
# Job group: 0
# Job type: Arrival
# Arrival Time 59.591089819523496
# Service Time: 2.1780381101808417
# Group 0 has a space.
# Job 28 will finish at 61.76912792970434
# -----------------------------
# Master clock: 60.84137989374016
# Job: 26
# Job group: 1
# Job type: Departure
# Arrival Time 55.48135948714256
# Service Time: 5.360020406597597
# Job 26 finished.
# -----------------------------
# Master clock: 61.64595498571396
# Job: 29
# Job group: 1
# Job type: Arrival
# Arrival Time 61.64595498571396
# Service Time: 3.2097188507572683
# Group 1 has a space
# Job 29 will finish at 64.85567383647123
# -----------------------------
# Master clock: 61.76912792970434
# Job: 28
# Job group: 0
# Job type: Departure
# Arrival Time 59.591089819523496
# Service Time: 2.1780381101808417
# Job 28 finished.
# -----------------------------
# Master clock: 63.70082015190443
# Job: 30
# Job group: 1
# Job type: Arrival
# Arrival Time 63.70082015190443
# Service Time: 5.678994672711219
# Group 1 has a space
# Job 30 will finish at 69.37981482461565
# -----------------------------
# Master clock: 64.85567383647123
# Job: 29
# Job group: 1
# Job type: Departure
# Arrival Time 61.64595498571396
# Service Time: 3.2097188507572683
# Job 29 finished.
# -----------------------------
# Master clock: 65.75568531809489
# Job: 31
# Job group: 0
# Job type: Arrival
# Arrival Time 65.75568531809489
# Service Time: 1.648872730541743
# Group 0 has a space.
# Job 31 will finish at 67.40455804863663
# -----------------------------
# Master clock: 67.40455804863663
# Job: 31
# Job group: 0
# Job type: Departure
# Arrival Time 65.75568531809489
# Service Time: 1.648872730541743
# Job 31 finished.
# -----------------------------
# Master clock: 67.81055048428536
# Job: 32
# Job group: 1
# Job type: Arrival
# Arrival Time 67.81055048428536
# Service Time: 3.0494953343046562
# Group 1 has a space
# Job 32 will finish at 70.86004581859001
# -----------------------------
# Master clock: 69.37981482461565
# Job: 30
# Job group: 1
# Job type: Departure
# Arrival Time 63.70082015190443
# Service Time: 5.678994672711219
# Job 30 finished.
# -----------------------------
# Master clock: 69.86541565047582
# Job: 33
# Job group: 1
# Job type: Arrival
# Arrival Time 69.86541565047582
# Service Time: 3.0437091003218537
# Group 1 has a space
# Job 33 will finish at 72.90912475079767
# -----------------------------
# Master clock: 70.86004581859001
# Job: 32
# Job group: 1
# Job type: Departure
# Arrival Time 67.81055048428536
# Service Time: 3.0494953343046562
# Job 32 finished.
# -----------------------------
# Master clock: 71.92028081666629
# Job: 34
# Job group: 1
# Job type: Arrival
# Arrival Time 71.92028081666629
# Service Time: 5.808262697746211
# Group 1 has a space
# Job 34 will finish at 77.72854351441251
# -----------------------------
# Master clock: 72.90912475079767
# Job: 33
# Job group: 1
# Job type: Departure
# Arrival Time 69.86541565047582
# Service Time: 3.0437091003218537
# Job 33 finished.
# -----------------------------
# Master clock: 73.97514598285676
# Job: 35
# Job group: 1
# Job type: Arrival
# Arrival Time 73.97514598285676
# Service Time: 3.1330967922388644
# Group 1 has a space
# Job 35 will finish at 77.10824277509562
# -----------------------------
# Master clock: 76.03001114904723
# Job: 36
# Job group: 0
# Job type: Arrival
# Arrival Time 76.03001114904723
# Service Time: 4.083659216765553
# Group 0 has a space.
# Job 36 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 77.10824277509562
# Job: 35
# Job group: 1
# Job type: Departure
# Arrival Time 73.97514598285676
# Service Time: 3.1330967922388644
# Job 35 finished.
# -----------------------------
# Master clock: 77.72854351441251
# Job: 34
# Job group: 1
# Job type: Departure
# Arrival Time 71.92028081666629
# Service Time: 5.808262697746211
# Job 34 finished.
# -----------------------------
# Master clock: 78.0848763152377
# Job: 37
# Job group: 0
# Job type: Arrival
# Arrival Time 78.0848763152377
# Service Time: 2.175317898359011
# Group 0 has a space.
# Job 37 will finish at 80.2601942135967
# -----------------------------
# Master clock: 79.13001114904722
# Job: 36
# Job group: R
# Job type: Departure
# Arrival Time 76.03001114904723
# Service Time: 4.083659216765553
# Job 36 has moved to group 1
# -----------------------------
# Master clock: 79.13001114904722
# Job: 36
# Job group: r0
# Job type: Arrival
# Arrival Time 76.03001114904723
# Service Time: 4.083659216765553
# Group 1 has a space
# Job 36 will finish at 83.21367036581277
# -----------------------------
# Master clock: 80.13974148142816
# Job: 38
# Job group: 0
# Job type: Arrival
# Arrival Time 80.13974148142816
# Service Time: 3.723976848854136
# Group 0 has a space.
# Job 38 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 80.2601942135967
# Job: 37
# Job group: 0
# Job type: Departure
# Arrival Time 78.0848763152377
# Service Time: 2.175317898359011
# Job 37 finished.
# -----------------------------
# Master clock: 82.19460664761863
# Job: 39
# Job group: 0
# Job type: Arrival
# Arrival Time 82.19460664761863
# Service Time: 1.6879536578935048
# Group 0 has a space.
# Job 39 will finish at 83.88256030551213
# -----------------------------
# Master clock: 83.21367036581277
# Job: 36
# Job group: r0
# Job type: Departure
# Arrival Time 76.03001114904723
# Service Time: 4.083659216765553
# Job 36 finished.
# -----------------------------
# Master clock: 83.23974148142815
# Job: 38
# Job group: R
# Job type: Departure
# Arrival Time 80.13974148142816
# Service Time: 3.723976848854136
# Job 38 has moved to group 1
# -----------------------------
# Master clock: 83.23974148142815
# Job: 38
# Job group: r0
# Job type: Arrival
# Arrival Time 80.13974148142816
# Service Time: 3.723976848854136
# Group 1 has a space
# Job 38 will finish at 86.96371833028229
# -----------------------------
# Master clock: 83.88256030551213
# Job: 39
# Job group: 0
# Job type: Departure
# Arrival Time 82.19460664761863
# Service Time: 1.6879536578935048
# Job 39 finished.
# -----------------------------
# Master clock: 84.2494718138091
# Job: 40
# Job group: 0
# Job type: Arrival
# Arrival Time 84.2494718138091
# Service Time: 1.6054313770065334
# Group 0 has a space.
# Job 40 will finish at 85.85490319081563
# -----------------------------
# Master clock: 85.85490319081563
# Job: 40
# Job group: 0
# Job type: Departure
# Arrival Time 84.2494718138091
# Service Time: 1.6054313770065334
# Job 40 finished.
# -----------------------------
# Master clock: 86.30433697999956
# Job: 41
# Job group: 0
# Job type: Arrival
# Arrival Time 86.30433697999956
# Service Time: 1.8092551395011935
# Group 0 has a space.
# Job 41 will finish at 88.11359211950075
# -----------------------------
# Master clock: 86.96371833028229
# Job: 38
# Job group: r0
# Job type: Departure
# Arrival Time 80.13974148142816
# Service Time: 3.723976848854136
# Job 38 finished.
# -----------------------------
# Master clock: 88.11359211950075
# Job: 41
# Job group: 0
# Job type: Departure
# Arrival Time 86.30433697999956
# Service Time: 1.8092551395011935
# Job 41 finished.
# -----------------------------
# Master clock: 88.35920214619003
# Job: 42
# Job group: 0
# Job type: Arrival
# Arrival Time 88.35920214619003
# Service Time: 3.226380556601642
# Group 0 has a space.
# Job 42 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 90.4140673123805
# Job: 43
# Job group: 1
# Job type: Arrival
# Arrival Time 90.4140673123805
# Service Time: 3.690443929050429
# Group 1 has a space
# Job 43 will finish at 94.10451124143093
# -----------------------------
# Master clock: 91.45920214619002
# Job: 42
# Job group: R
# Job type: Departure
# Arrival Time 88.35920214619003
# Service Time: 3.226380556601642
# Job 42 has moved to group 1
# -----------------------------
# Master clock: 91.45920214619002
# Job: 42
# Job group: r0
# Job type: Arrival
# Arrival Time 88.35920214619003
# Service Time: 3.226380556601642
# Group 1 has a space
# Job 42 will finish at 94.68558270279166
# -----------------------------
# Master clock: 92.46893247857096
# Job: 44
# Job group: 1
# Job type: Arrival
# Arrival Time 92.46893247857096
# Service Time: 4.993741162755924
# Group 1 has a space
# Job 44 will finish at 97.46267364132689
# -----------------------------
# Master clock: 94.10451124143093
# Job: 43
# Job group: 1
# Job type: Departure
# Arrival Time 90.4140673123805
# Service Time: 3.690443929050429
# Job 43 finished.
# -----------------------------
# Master clock: 94.52379764476143
# Job: 45
# Job group: 0
# Job type: Arrival
# Arrival Time 94.52379764476143
# Service Time: 2.3994298085813206
# Group 0 has a space.
# Job 45 will finish at 96.92322745334275
# -----------------------------
# Master clock: 94.68558270279166
# Job: 42
# Job group: r0
# Job type: Departure
# Arrival Time 88.35920214619003
# Service Time: 3.226380556601642
# Job 42 finished.
# -----------------------------
# Master clock: 96.5786628109519
# Job: 46
# Job group: 0
# Job type: Arrival
# Arrival Time 96.5786628109519
# Service Time: 1.9833159259631197
# Group 0 has a space.
# Job 46 will finish at 98.56197873691502
# -----------------------------
# Master clock: 96.92322745334275
# Job: 45
# Job group: 0
# Job type: Departure
# Arrival Time 94.52379764476143
# Service Time: 2.3994298085813206
# Job 45 finished.
# -----------------------------
# Master clock: 97.46267364132689
# Job: 44
# Job group: 1
# Job type: Departure
# Arrival Time 92.46893247857096
# Service Time: 4.993741162755924
# Job 44 finished.
# -----------------------------
# Master clock: 98.56197873691502
# Job: 46
# Job group: 0
# Job type: Departure
# Arrival Time 96.5786628109519
# Service Time: 1.9833159259631197
# Job 46 finished.
# -----------------------------
# Master clock: 98.63352797714236
# Job: 47
# Job group: 0
# Job type: Arrival
# Arrival Time 98.63352797714236
# Service Time: 1.9401125579155958
# Group 0 has a space.
# Job 47 will finish at 100.57364053505796
# -----------------------------
# Master clock: 100.57364053505796
# Job: 47
# Job group: 0
# Job type: Departure
# Arrival Time 98.63352797714236
# Service Time: 1.9401125579155958
# Job 47 finished.
# -----------------------------
# Master clock: 100.68839314333283
# Job: 48
# Job group: 0
# Job type: Arrival
# Arrival Time 100.68839314333283
# Service Time: 2.405762112278263
# Group 0 has a space.
# Job 48 will finish at 103.0941552556111
# -----------------------------
# Master clock: 102.7432583095233
# Job: 49
# Job group: 1
# Job type: Arrival
# Arrival Time 102.7432583095233
# Service Time: 3.1506383064277115
# Group 1 has a space
# Job 49 will finish at 105.89389661595101
# -----------------------------
# Master clock: 103.0941552556111
# Job: 48
# Job group: 0
# Job type: Departure
# Arrival Time 100.68839314333283
# Service Time: 2.405762112278263
# Job 48 finished.
# -----------------------------
# Master clock: 104.79812347571377
# Job: 50
# Job group: 1
# Job type: Arrival
# Arrival Time 104.79812347571377
# Service Time: 8.222470000383003
# Group 1 has a space
# Job 50 will finish at 113.02059347609676
# -----------------------------
# Master clock: 105.89389661595101
# Job: 49
# Job group: 1
# Job type: Departure
# Arrival Time 102.7432583095233
# Service Time: 3.1506383064277115
# Job 49 finished.
# -----------------------------
# Master clock: 106.85298864190423
# Job: 51
# Job group: 0
# Job type: Arrival
# Arrival Time 106.85298864190423
# Service Time: 2.925263389243014
# Group 0 has a space.
# Job 51 will finish at 109.77825203114725
# -----------------------------
# Master clock: 108.9078538080947
# Job: 52
# Job group: 0
# Job type: Arrival
# Arrival Time 108.9078538080947
# Service Time: 1.5847631665153774
# Group 0 has a space.
# Job 52 will finish at 110.49261697461007
# -----------------------------
# Master clock: 109.77825203114725
# Job: 51
# Job group: 0
# Job type: Departure
# Arrival Time 106.85298864190423
# Service Time: 2.925263389243014
# Job 51 finished.
# -----------------------------
# Master clock: 110.49261697461007
# Job: 52
# Job group: 0
# Job type: Departure
# Arrival Time 108.9078538080947
# Service Time: 1.5847631665153774
# Job 52 finished.
# -----------------------------
# Master clock: 110.96271897428517
# Job: 53
# Job group: 1
# Job type: Arrival
# Arrival Time 110.96271897428517
# Service Time: 3.3026071662976304
# Group 1 has a space
# Job 53 will finish at 114.2653261405828
# -----------------------------
# Master clock: 113.01758414047563
# Job: 54
# Job group: 0
# Job type: Arrival
# Arrival Time 113.01758414047563
# Service Time: 2.0456911737527754
# Group 0 has a space.
# Job 54 will finish at 115.0632753142284
# -----------------------------
# Master clock: 113.02059347609676
# Job: 50
# Job group: 1
# Job type: Departure
# Arrival Time 104.79812347571377
# Service Time: 8.222470000383003
# Job 50 finished.
# -----------------------------
# Master clock: 114.2653261405828
# Job: 53
# Job group: 1
# Job type: Departure
# Arrival Time 110.96271897428517
# Service Time: 3.3026071662976304
# Job 53 finished.
# -----------------------------
# Master clock: 115.0632753142284
# Job: 54
# Job group: 0
# Job type: Departure
# Arrival Time 113.01758414047563
# Service Time: 2.0456911737527754
# Job 54 finished.
# -----------------------------
# Master clock: 115.0724493066661
# Job: 55
# Job group: 1
# Job type: Arrival
# Arrival Time 115.0724493066661
# Service Time: 3.9411540169994166
# Group 1 has a space
# Job 55 will finish at 119.01360332366552
# -----------------------------
# Master clock: 117.12731447285657
# Job: 56
# Job group: 0
# Job type: Arrival
# Arrival Time 117.12731447285657
# Service Time: 1.5249128308657398
# Group 0 has a space.
# Job 56 will finish at 118.65222730372231
# -----------------------------
# Master clock: 118.65222730372231
# Job: 56
# Job group: 0
# Job type: Departure
# Arrival Time 117.12731447285657
# Service Time: 1.5249128308657398
# Job 56 finished.
# -----------------------------
# Master clock: 119.01360332366552
# Job: 55
# Job group: 1
# Job type: Departure
# Arrival Time 115.0724493066661
# Service Time: 3.9411540169994166
# Job 55 finished.
# -----------------------------
# Master clock: 119.18217963904704
# Job: 57
# Job group: 1
# Job type: Arrival
# Arrival Time 119.18217963904704
# Service Time: 5.96514606784994
# Group 1 has a space
# Job 57 will finish at 125.14732570689698
# -----------------------------
# Master clock: 121.2370448052375
# Job: 58
# Job group: 0
# Job type: Arrival
# Arrival Time 121.2370448052375
# Service Time: 1.4983918593514676
# Group 0 has a space.
# Job 58 will finish at 122.73543666458897
# -----------------------------
# Master clock: 122.73543666458897
# Job: 58
# Job group: 0
# Job type: Departure
# Arrival Time 121.2370448052375
# Service Time: 1.4983918593514676
# Job 58 finished.
# -----------------------------
# Master clock: 123.29190997142797
# Job: 59
# Job group: 0
# Job type: Arrival
# Arrival Time 123.29190997142797
# Service Time: 8.16240212600649
# Group 0 has a space.
# Job 59 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 125.14732570689698
# Job: 57
# Job group: 1
# Job type: Departure
# Arrival Time 119.18217963904704
# Service Time: 5.96514606784994
# Job 57 finished.
# -----------------------------
# Master clock: 125.34677513761844
# Job: 60
# Job group: 1
# Job type: Arrival
# Arrival Time 125.34677513761844
# Service Time: 3.3046848017785715
# Group 1 has a space
# Job 60 will finish at 128.651459939397
# -----------------------------
# Master clock: 126.39190997142796
# Job: 59
# Job group: R
# Job type: Departure
# Arrival Time 123.29190997142797
# Service Time: 8.16240212600649
# Job 59 has moved to group 1
# -----------------------------
# Master clock: 126.39190997142796
# Job: 59
# Job group: r0
# Job type: Arrival
# Arrival Time 123.29190997142797
# Service Time: 8.16240212600649
# Group 1 has a space
# Job 59 will finish at 134.55431209743446
# -----------------------------
# Master clock: 127.4016403038089
# Job: 61
# Job group: 0
# Job type: Arrival
# Arrival Time 127.4016403038089
# Service Time: 1.6756022017191992
# Group 0 has a space.
# Job 61 will finish at 129.0772425055281
# -----------------------------
# Master clock: 128.651459939397
# Job: 60
# Job group: 1
# Job type: Departure
# Arrival Time 125.34677513761844
# Service Time: 3.3046848017785715
# Job 60 finished.
# -----------------------------
# Master clock: 129.0772425055281
# Job: 61
# Job group: 0
# Job type: Departure
# Arrival Time 127.4016403038089
# Service Time: 1.6756022017191992
# Job 61 finished.
# -----------------------------
# Master clock: 129.45650546999937
# Job: 62
# Job group: 1
# Job type: Arrival
# Arrival Time 129.45650546999937
# Service Time: 4.060111882537564
# Group 1 has a space
# Job 62 will finish at 133.51661735253694
# -----------------------------
# Master clock: 131.51137063618984
# Job: 63
# Job group: 0
# Job type: Arrival
# Arrival Time 131.51137063618984
# Service Time: 1.521767212472197
# Group 0 has a space.
# Job 63 will finish at 133.03313784866202
# -----------------------------
# Master clock: 133.03313784866202
# Job: 63
# Job group: 0
# Job type: Departure
# Arrival Time 131.51137063618984
# Service Time: 1.521767212472197
# Job 63 finished.
# -----------------------------
# Master clock: 133.51661735253694
# Job: 62
# Job group: 1
# Job type: Departure
# Arrival Time 129.45650546999937
# Service Time: 4.060111882537564
# Job 62 finished.
# -----------------------------
# Master clock: 133.5662358023803
# Job: 64
# Job group: 0
# Job type: Arrival
# Arrival Time 133.5662358023803
# Service Time: 1.9178652118157937
# Group 0 has a space.
# Job 64 will finish at 135.48410101419609
# -----------------------------
# Master clock: 134.55431209743446
# Job: 59
# Job group: r0
# Job type: Departure
# Arrival Time 123.29190997142797
# Service Time: 8.16240212600649
# Job 59 finished.
# -----------------------------
# Master clock: 135.48410101419609
# Job: 64
# Job group: 0
# Job type: Departure
# Arrival Time 133.5662358023803
# Service Time: 1.9178652118157937
# Job 64 finished.
# -----------------------------
# Master clock: 135.62110096857077
# Job: 65
# Job group: 0
# Job type: Arrival
# Arrival Time 135.62110096857077
# Service Time: 2.0113618406756824
# Group 0 has a space.
# Job 65 will finish at 137.63246280924645
# -----------------------------
# Master clock: 137.63246280924645
# Job: 65
# Job group: 0
# Job type: Departure
# Arrival Time 135.62110096857077
# Service Time: 2.0113618406756824
# Job 65 finished.
# -----------------------------
# Master clock: 137.67596613476124
# Job: 66
# Job group: 1
# Job type: Arrival
# Arrival Time 137.67596613476124
# Service Time: 4.541028171595108
# Group 1 has a space
# Job 66 will finish at 142.21699430635636
# -----------------------------
# Master clock: 139.7308313009517
# Job: 67
# Job group: 0
# Job type: Arrival
# Arrival Time 139.7308313009517
# Service Time: 1.7619893829969604
# Group 0 has a space.
# Job 67 will finish at 141.49282068394868
# -----------------------------
# Master clock: 141.49282068394868
# Job: 67
# Job group: 0
# Job type: Departure
# Arrival Time 139.7308313009517
# Service Time: 1.7619893829969604
# Job 67 finished.
# -----------------------------
# Master clock: 141.78569646714217
# Job: 68
# Job group: 1
# Job type: Arrival
# Arrival Time 141.78569646714217
# Service Time: 3.951907590512186
# Group 1 has a space
# Job 68 will finish at 145.73760405765435
# -----------------------------
# Master clock: 142.21699430635636
# Job: 66
# Job group: 1
# Job type: Departure
# Arrival Time 137.67596613476124
# Service Time: 4.541028171595108
# Job 66 finished.
# -----------------------------
# Master clock: 143.84056163333264
# Job: 69
# Job group: 0
# Job type: Arrival
# Arrival Time 143.84056163333264
# Service Time: 2.1332776997853036
# Group 0 has a space.
# Job 69 will finish at 145.97383933311795
# -----------------------------
# Master clock: 145.73760405765435
# Job: 68
# Job group: 1
# Job type: Departure
# Arrival Time 141.78569646714217
# Service Time: 3.951907590512186
# Job 68 finished.
# -----------------------------
# Master clock: 145.8954267995231
# Job: 70
# Job group: 1
# Job type: Arrival
# Arrival Time 145.8954267995231
# Service Time: 3.5831816195376667
# Group 1 has a space
# Job 70 will finish at 149.47860841906078
# -----------------------------
# Master clock: 145.97383933311795
# Job: 69
# Job group: 0
# Job type: Departure
# Arrival Time 143.84056163333264
# Service Time: 2.1332776997853036
# Job 69 finished.
# -----------------------------
# Master clock: 147.95029196571357
# Job: 71
# Job group: 1
# Job type: Arrival
# Arrival Time 147.95029196571357
# Service Time: 3.814286902294139
# Group 1 has a space
# Job 71 will finish at 151.7645788680077
# -----------------------------
# Master clock: 149.47860841906078
# Job: 70
# Job group: 1
# Job type: Departure
# Arrival Time 145.8954267995231
# Service Time: 3.5831816195376667
# Job 70 finished.
# -----------------------------
# Master clock: 150.00515713190404
# Job: 72
# Job group: 0
# Job type: Arrival
# Arrival Time 150.00515713190404
# Service Time: 2.227327727058232
# Group 0 has a space.
# Job 72 will finish at 152.23248485896227
# -----------------------------
# Master clock: 151.7645788680077
# Job: 71
# Job group: 1
# Job type: Departure
# Arrival Time 147.95029196571357
# Service Time: 3.814286902294139
# Job 71 finished.
# -----------------------------
# Master clock: 152.0600222980945
# Job: 73
# Job group: 0
# Job type: Arrival
# Arrival Time 152.0600222980945
# Service Time: 2.0479838544106266
# Group 0 has a space.
# Job 73 will finish at 154.10800615250514
# -----------------------------
# Master clock: 152.23248485896227
# Job: 72
# Job group: 0
# Job type: Departure
# Arrival Time 150.00515713190404
# Service Time: 2.227327727058232
# Job 72 finished.
# -----------------------------
# Master clock: 154.10800615250514
# Job: 73
# Job group: 0
# Job type: Departure
# Arrival Time 152.0600222980945
# Service Time: 2.0479838544106266
# Job 73 finished.
# -----------------------------
# Master clock: 154.11488746428498
# Job: 74
# Job group: 1
# Job type: Arrival
# Arrival Time 154.11488746428498
# Service Time: 5.847561665263267
# Group 1 has a space
# Job 74 will finish at 159.96244912954825
# -----------------------------
# Master clock: 156.16975263047544
# Job: 75
# Job group: 0
# Job type: Arrival
# Arrival Time 156.16975263047544
# Service Time: 2.3012337057141123
# Group 0 has a space.
# Job 75 will finish at 158.47098633618955
# -----------------------------
# Master clock: 158.2246177966659
# Job: 76
# Job group: 0
# Job type: Arrival
# Arrival Time 158.2246177966659
# Service Time: 4.5788335659703385
# Group 0 has a space.
# Job 76 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 158.47098633618955
# Job: 75
# Job group: 0
# Job type: Departure
# Arrival Time 156.16975263047544
# Service Time: 2.3012337057141123
# Job 75 finished.
# -----------------------------
# Master clock: 159.96244912954825
# Job: 74
# Job group: 1
# Job type: Departure
# Arrival Time 154.11488746428498
# Service Time: 5.847561665263267
# Job 74 finished.
# -----------------------------
# Master clock: 160.27948296285638
# Job: 77
# Job group: 1
# Job type: Arrival
# Arrival Time 160.27948296285638
# Service Time: 5.068036580572931
# Group 1 has a space
# Job 77 will finish at 165.3475195434293
# -----------------------------
# Master clock: 161.3246177966659
# Job: 76
# Job group: R
# Job type: Departure
# Arrival Time 158.2246177966659
# Service Time: 4.5788335659703385
# Job 76 has moved to group 1
# -----------------------------
# Master clock: 161.3246177966659
# Job: 76
# Job group: r0
# Job type: Arrival
# Arrival Time 158.2246177966659
# Service Time: 4.5788335659703385
# Group 1 has a space
# Job 76 will finish at 165.90345136263625
# -----------------------------
# Master clock: 162.33434812904684
# Job: 78
# Job group: 0
# Job type: Arrival
# Arrival Time 162.33434812904684
# Service Time: 1.6385834108120605
# Group 0 has a space.
# Job 78 will finish at 163.9729315398589
# -----------------------------
# Master clock: 163.9729315398589
# Job: 78
# Job group: 0
# Job type: Departure
# Arrival Time 162.33434812904684
# Service Time: 1.6385834108120605
# Job 78 finished.
# -----------------------------
# Master clock: 164.3892132952373
# Job: 79
# Job group: 0
# Job type: Arrival
# Arrival Time 164.3892132952373
# Service Time: 1.5149852738958336
# Group 0 has a space.
# Job 79 will finish at 165.90419856913314
# -----------------------------
# Master clock: 165.3475195434293
# Job: 77
# Job group: 1
# Job type: Departure
# Arrival Time 160.27948296285638
# Service Time: 5.068036580572931
# Job 77 finished.
# -----------------------------
# Master clock: 165.90345136263625
# Job: 76
# Job group: r0
# Job type: Departure
# Arrival Time 158.2246177966659
# Service Time: 4.5788335659703385
# Job 76 finished.
# -----------------------------
# Master clock: 165.90419856913314
# Job: 79
# Job group: 0
# Job type: Departure
# Arrival Time 164.3892132952373
# Service Time: 1.5149852738958336
# Job 79 finished.
# -----------------------------
# Master clock: 166.44407846142778
# Job: 80
# Job group: 1
# Job type: Arrival
# Arrival Time 166.44407846142778
# Service Time: 3.1861955417163617
# Group 1 has a space
# Job 80 will finish at 169.63027400314414
# -----------------------------
# Master clock: 168.49894362761825
# Job: 81
# Job group: 1
# Job type: Arrival
# Arrival Time 168.49894362761825
# Service Time: 3.021253565826224
# Group 1 has a space
# Job 81 will finish at 171.52019719344446
# -----------------------------
# Master clock: 169.63027400314414
# Job: 80
# Job group: 1
# Job type: Departure
# Arrival Time 166.44407846142778
# Service Time: 3.1861955417163617
# Job 80 finished.
# -----------------------------
# Master clock: 170.5538087938087
# Job: 82
# Job group: 0
# Job type: Arrival
# Arrival Time 170.5538087938087
# Service Time: 1.6895241198212494
# Group 0 has a space.
# Job 82 will finish at 172.24333291362996
# -----------------------------
# Master clock: 171.52019719344446
# Job: 81
# Job group: 1
# Job type: Departure
# Arrival Time 168.49894362761825
# Service Time: 3.021253565826224
# Job 81 finished.
# -----------------------------
# Master clock: 172.24333291362996
# Job: 82
# Job group: 0
# Job type: Departure
# Arrival Time 170.5538087938087
# Service Time: 1.6895241198212494
# Job 82 finished.
# -----------------------------
# Master clock: 172.60867395999918
# Job: 83
# Job group: 1
# Job type: Arrival
# Arrival Time 172.60867395999918
# Service Time: 3.8700597162284223
# Group 1 has a space
# Job 83 will finish at 176.4787336762276
# -----------------------------
# Master clock: 174.66353912618965
# Job: 84
# Job group: 0
# Job type: Arrival
# Arrival Time 174.66353912618965
# Service Time: 1.5927578488828684
# Group 0 has a space.
# Job 84 will finish at 176.2562969750725
# -----------------------------
# Master clock: 176.2562969750725
# Job: 84
# Job group: 0
# Job type: Departure
# Arrival Time 174.66353912618965
# Service Time: 1.5927578488828684
# Job 84 finished.
# -----------------------------
# Master clock: 176.4787336762276
# Job: 83
# Job group: 1
# Job type: Departure
# Arrival Time 172.60867395999918
# Service Time: 3.8700597162284223
# Job 83 finished.
# -----------------------------
# Master clock: 176.71840429238011
# Job: 85
# Job group: 0
# Job type: Arrival
# Arrival Time 176.71840429238011
# Service Time: 2.1653494805891182
# Group 0 has a space.
# Job 85 will finish at 178.88375377296924
# -----------------------------
# Master clock: 178.77326945857058
# Job: 86
# Job group: 1
# Job type: Arrival
# Arrival Time 178.77326945857058
# Service Time: 4.129208635284305
# Group 1 has a space
# Job 86 will finish at 182.90247809385488
# -----------------------------
# Master clock: 178.88375377296924
# Job: 85
# Job group: 0
# Job type: Departure
# Arrival Time 176.71840429238011
# Service Time: 2.1653494805891182
# Job 85 finished.
# -----------------------------
# Master clock: 180.82813462476105
# Job: 87
# Job group: 1
# Job type: Arrival
# Arrival Time 180.82813462476105
# Service Time: 3.06044997202049
# Group 1 has a space
# Job 87 will finish at 183.88858459678153
# -----------------------------
# Master clock: 182.88299979095152
# Job: 88
# Job group: 1
# Job type: Arrival
# Arrival Time 182.88299979095152
# Service Time: 3.6732894635764564
# Group 1 has a space
# Job 88 will finish at 186.55628925452797
# -----------------------------
# Master clock: 182.90247809385488
# Job: 86
# Job group: 1
# Job type: Departure
# Arrival Time 178.77326945857058
# Service Time: 4.129208635284305
# Job 86 finished.
# -----------------------------
# Master clock: 183.88858459678153
# Job: 87
# Job group: 1
# Job type: Departure
# Arrival Time 180.82813462476105
# Service Time: 3.06044997202049
# Job 87 finished.
# -----------------------------
# Master clock: 184.93786495714198
# Job: 89
# Job group: 0
# Job type: Arrival
# Arrival Time 184.93786495714198
# Service Time: 3.9306577895926638
# Group 0 has a space.
# Job 89 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 186.55628925452797
# Job: 88
# Job group: 1
# Job type: Departure
# Arrival Time 182.88299979095152
# Service Time: 3.6732894635764564
# Job 88 finished.
# -----------------------------
# Master clock: 186.99273012333245
# Job: 90
# Job group: 1
# Job type: Arrival
# Arrival Time 186.99273012333245
# Service Time: 3.952399580297395
# Group 1 has a space
# Job 90 will finish at 190.94512970362985
# -----------------------------
# Master clock: 188.03786495714198
# Job: 89
# Job group: R
# Job type: Departure
# Arrival Time 184.93786495714198
# Service Time: 3.9306577895926638
# Job 89 has moved to group 1
# -----------------------------
# Master clock: 188.03786495714198
# Job: 89
# Job group: r0
# Job type: Arrival
# Arrival Time 184.93786495714198
# Service Time: 3.9306577895926638
# Group 1 has a space
# Job 89 will finish at 191.96852274673464
# -----------------------------
# Master clock: 189.04759528952292
# Job: 91
# Job group: 0
# Job type: Arrival
# Arrival Time 189.04759528952292
# Service Time: 2.102504462182241
# Group 0 has a space.
# Job 91 will finish at 191.15009975170517
# -----------------------------
# Master clock: 190.94512970362985
# Job: 90
# Job group: 1
# Job type: Departure
# Arrival Time 186.99273012333245
# Service Time: 3.952399580297395
# Job 90 finished.
# -----------------------------
# Master clock: 191.10246045571338
# Job: 92
# Job group: 0
# Job type: Arrival
# Arrival Time 191.10246045571338
# Service Time: 1.8841936587294021
# Group 0 has a space.
# Job 92 will finish at 192.98665411444279
# -----------------------------
# Master clock: 191.15009975170517
# Job: 91
# Job group: 0
# Job type: Departure
# Arrival Time 189.04759528952292
# Service Time: 2.102504462182241
# Job 91 finished.
# -----------------------------
# Master clock: 191.96852274673464
# Job: 89
# Job group: r0
# Job type: Departure
# Arrival Time 184.93786495714198
# Service Time: 3.9306577895926638
# Job 89 finished.
# -----------------------------
# Master clock: 192.98665411444279
# Job: 92
# Job group: 0
# Job type: Departure
# Arrival Time 191.10246045571338
# Service Time: 1.8841936587294021
# Job 92 finished.
# -----------------------------
# Master clock: 193.15732562190385
# Job: 93
# Job group: 0
# Job type: Arrival
# Arrival Time 193.15732562190385
# Service Time: 1.5305167422852002
# Group 0 has a space.
# Job 93 will finish at 194.68784236418904
# -----------------------------
# Master clock: 194.68784236418904
# Job: 93
# Job group: 0
# Job type: Departure
# Arrival Time 193.15732562190385
# Service Time: 1.5305167422852002
# Job 93 finished.
# -----------------------------
# Master clock: 195.21219078809432
# Job: 94
# Job group: 1
# Job type: Arrival
# Arrival Time 195.21219078809432
# Service Time: 3.1608817577764845
# Group 1 has a space
# Job 94 will finish at 198.3730725458708
# -----------------------------
# Master clock: 197.26705595428479
# Job: 95
# Job group: 0
# Job type: Arrival
# Arrival Time 197.26705595428479
# Service Time: 3.7777155340082613
# Group 0 has a space.
# Job 95 cannot finish, need to go to group1 later.
# -----------------------------
# Master clock: 198.3730725458708
# Job: 94
# Job group: 1
# Job type: Departure
# Arrival Time 195.21219078809432
# Service Time: 3.1608817577764845
# Job 94 finished.
# -----------------------------
# Master clock: 199.32192112047525
# Job: 96
# Job group: 0
# Job type: Arrival
# Arrival Time 199.32192112047525
# Service Time: 1.815077033832157
# Group 0 has a space.
# Job 96 will finish at 201.1369981543074
# -----------------------------
# Master clock: 200.36705595428478
# Job: 95
# Job group: R
# Job type: Departure
# Arrival Time 197.26705595428479
# Service Time: 3.7777155340082613
# Job 95 has moved to group 1
# -----------------------------
# Master clock: 200.36705595428478
# Job: 95
# Job group: r0
# Job type: Arrival
# Arrival Time 197.26705595428479
# Service Time: 3.7777155340082613
# Group 1 has a space
# Job 95 will finish at 204.14477148829303
# -----------------------------
# Master clock: 201.1369981543074
# Job: 96
# Job group: 0
# Job type: Departure
# Arrival Time 199.32192112047525
# Service Time: 1.815077033832157
# Job 96 finished.
# -----------------------------
# Master clock: 204.14477148829303
# Job: 95
# Job group: r0
# Job type: Departure
# Arrival Time 197.26705595428479
# Service Time: 3.7777155340082613
# Job 95 finished.
# -----------------------------
# [(2.0548651661904644, 3.93399073046924, '0'), (6.164595498571393, 10.08277285929674, '1'), (4.109730332380929, 10.979850602883403, 'r0'), (10.274325830952321, 12.517783841867526, '0'), (8.219460664761858, 12.878906985510788, '1'), (12.329190997142785, 14.675262814456444, '0'), (16.438921329523712, 18.36656114510979, '0'), (14.384056163333248, 21.56587534202121, 'r0'), (18.493786495714176, 21.75429529162902, '1'), (20.54865166190464, 22.50414595702267, '0'), (22.603516828095103, 24.118312341979617, '0'), (26.71324716047603, 28.437813125032854, '0'), (28.768112326666493, 31.020926491553595, '0'), (24.658381994285566, 31.96813767982039, 'r0'), (30.822977492856957, 32.57509756717531, '0'), (32.877842659047424, 35.09516486389878, '0'), (34.93270782523789, 36.859278490401465, '0'), (39.042438157618825, 40.61090109935231, '0'), (36.98757299142836, 40.81996905529668, '1'), (41.09730332380929, 44.47700509271429, '1'), (43.15216848999976, 45.38321314866829, '0'), (45.20703365619023, 48.252085474790285, '0'), (47.261898822380694, 50.766908475868476, '1'), (49.31676398857116, 51.72244640073784, '0'), (51.37162915476163, 53.28418070250526, '0'), (53.426494320952095, 55.23045931257501, '0'), (57.53622465333303, 59.077339446298026, '0'), (55.48135948714256, 60.84137989374016, '1'), (59.591089819523496, 61.76912792970434, '0'), (61.64595498571396, 64.85567383647123, '1'), (65.75568531809489, 67.40455804863663, '0'), (63.70082015190443, 69.37981482461565, '1'), (67.81055048428536, 70.86004581859001, '1'), (69.86541565047582, 72.90912475079767, '1'), (73.97514598285676, 77.10824277509562, '1'), (71.92028081666629, 77.72854351441251, '1'), (78.0848763152377, 80.2601942135967, '0'), (76.03001114904723, 83.21367036581277, 'r0'), (82.19460664761863, 83.88256030551213, '0'), (84.2494718138091, 85.85490319081563, '0'), (80.13974148142816, 86.96371833028229, 'r0'), (86.30433697999956, 88.11359211950075, '0'), (90.4140673123805, 94.10451124143093, '1'), (88.35920214619003, 94.68558270279166, 'r0'), (94.52379764476143, 96.92322745334275, '0'), (92.46893247857096, 97.46267364132689, '1'), (96.5786628109519, 98.56197873691502, '0'), (98.63352797714236, 100.57364053505796, '0'), (100.68839314333283, 103.0941552556111, '0'), (102.7432583095233, 105.89389661595101, '1'), (106.85298864190423, 109.77825203114725, '0'), (108.9078538080947, 110.49261697461007, '0'), (104.79812347571377, 113.02059347609676, '1'), (110.96271897428517, 114.2653261405828, '1'), (113.01758414047563, 115.0632753142284, '0'), (117.12731447285657, 118.65222730372231, '0'), (115.0724493066661, 119.01360332366552, '1'), (121.2370448052375, 122.73543666458897, '0'), (119.18217963904704, 125.14732570689698, '1'), (125.34677513761844, 128.651459939397, '1'), (127.4016403038089, 129.0772425055281, '0'), (131.51137063618984, 133.03313784866202, '0'), (129.45650546999937, 133.51661735253694, '1'), (123.29190997142797, 134.55431209743446, 'r0'), (133.5662358023803, 135.48410101419609, '0'), (135.62110096857077, 137.63246280924645, '0'), (139.7308313009517, 141.49282068394868, '0'), (137.67596613476124, 142.21699430635636, '1'), (141.78569646714217, 145.73760405765435, '1'), (143.84056163333264, 145.97383933311795, '0'), (145.8954267995231, 149.47860841906078, '1'), (147.95029196571357, 151.7645788680077, '1'), (150.00515713190404, 152.23248485896227, '0'), (152.0600222980945, 154.10800615250514, '0'), (156.16975263047544, 158.47098633618955, '0'), (154.11488746428498, 159.96244912954825, '1'), (162.33434812904684, 163.9729315398589, '0'), (160.27948296285638, 165.3475195434293, '1'), (158.2246177966659, 165.90345136263625, 'r0'), (164.3892132952373, 165.90419856913314, '0'), (166.44407846142778, 169.63027400314414, '1'), (168.49894362761825, 171.52019719344446, '1'), (170.5538087938087, 172.24333291362996, '0'), (174.66353912618965, 176.2562969750725, '0'), (172.60867395999918, 176.4787336762276, '1'), (176.71840429238011, 178.88375377296924, '0'), (178.77326945857058, 182.90247809385488, '1'),  ...
# 1.9449463501961073 4.092479886525263
